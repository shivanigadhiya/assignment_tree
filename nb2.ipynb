# %% [markdown]
# Q1. What is Bayes' Theorem?
# Bayes' theorem is a mathematical formula used to determine the probability of an event based on prior knowledge of conditions related to the event. It helps update probabilities as new evidence is introduced.
# Q2. What is the formula for Bayes' Theorem?
# The formula is:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) = Posterior probability (probability of A given B)
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) = Likelihood (probability of B given A)
# 𝑃
# (
# 𝐴
# )
# P(A) = Prior probability of A
# 𝑃
# (
# 𝐵
# )
# P(B) = Total probability of B
# Q3. How is Bayes' Theorem used in practice?
# Bayes' theorem is widely used in:
#
# Spam filtering (classifying emails as spam or not)
# Medical diagnosis (determining disease probability given symptoms)
# Machine learning & classification algorithms (e.g., Naïve Bayes classifier)
# Risk assessment (fraud detection, credit scoring)
# Speech and image recognition
#
# Q4. What is the relationship between Bayes' Theorem and Conditional Probability?
# Bayes' theorem is derived from conditional probability. Conditional probability defines the likelihood of an event occurring given that another event has already occurred. Bayes' theorem reverses the conditional probability, updating the probability of a cause given observed evidence.
#
# Q5. How do you choose which type of Naive Bayes classifier to use for any given problem?
# The type of Naive Bayes classifier depends on the nature of the feature data:
#
# Gaussian Naive Bayes – Used when features are continuous and assumed to follow a normal distribution. Suitable for real-valued data.
# Multinomial Naive Bayes – Used when features represent discrete counts, such as word frequencies in text classification.
# Bernoulli Naive Bayes – Used for binary features, such as presence or absence of words in a document.
# Categorical Naive Bayes – Used when features are categorical with multiple discrete values (not necessarily counts).
# For example:
#
# Spam detection → Multinomial or Bernoulli NB
# Text classification → Multinomial NB
# Medical diagnosis (with continuous data) → Gaussian NB
# Q6. Assignment: Naive Bayes Classification
# We use the Naive Bayes classification rule:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# ,
# 𝑋
# 2
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝑋
# 2
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝐴
# )
# P(A∣X
# 1
# ​
#  ,X
# 2
# ​
#  )∝P(X
# 1
# ​
#  ∣A)P(X
# 2
# ​
#  ∣A)P(A)
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# ,
# 𝑋
# 2
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# ∣
# 𝐵
# )
# 𝑃
# (
# 𝑋
# 2
# ∣
# 𝐵
# )
# 𝑃
# (
# 𝐵
# )
# P(B∣X
# 1
# ​
#  ,X
# 2
# ​
#  )∝P(X
# 1
# ​
#  ∣B)P(X
# 2
# ​
#  ∣B)P(B)
# Step 1: Calculate Prior Probabilities
# Since we assume equal priors:
#
# 𝑃
# (
# 𝐴
# )
# =
# 𝑃
# (
# 𝐵
# )
# =
# 0.5
# P(A)=P(B)=0.5
# Step 2: Calculate Likelihoods
# Using Laplace Smoothing (to avoid zero probabilities), we compute:
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐴
# )
# =
# 4
# +
# 1
# (
# 3
# +
# 3
# +
# 4
# +
# 1
# )
# =
# 5
# 11
# P(X
# 1
# ​
#  =3∣A)=
# (3+3+4+1)
# 4+1
# ​
#  =
# 11
# 5
# ​
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐵
# )
# =
# 1
# +
# 1
# (
# 2
# +
# 2
# +
# 1
# +
# 1
# )
# =
# 2
# 6
# P(X
# 1
# ​
#  =3∣B)=
# (2+2+1+1)
# 1+1
# ​
#  =
# 6
# 2
# ​
#
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐴
# )
# =
# 3
# +
# 1
# (
# 4
# +
# 3
# +
# 3
# +
# 3
# )
# =
# 4
# 13
# P(X
# 2
# ​
#  =4∣A)=
# (4+3+3+3)
# 3+1
# ​
#  =
# 13
# 4
# ​
#
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐵
# )
# =
# 3
# +
# 1
# (
# 2
# +
# 2
# +
# 2
# +
# 3
# )
# =
# 4
# 9
# P(X
# 2
# ​
#  =4∣B)=
# (2+2+2+3)
# 3+1
# ​
#  =
# 9
# 4
# ​
#
# Step 3: Compute Posterior Probabilities (Ignoring P(X))
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# P(A∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4)∝P(X
# 1
# ​
#  =3∣A)⋅P(X
# 2
# ​
#  =4∣A)⋅P(A)
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# (
# 5
# 11
# ×
# 4
# 13
# ×
# 0.5
# )
# P(A∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4)∝(
# 11
# 5
# ​
#  ×
# 13
# 4
# ​
#  ×0.5)
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐵
# )
# ⋅
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐵
# )
# ⋅
# 𝑃
# (
# 𝐵
# )
# P(B∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4)∝P(X
# 1
# ​
#  =3∣B)⋅P(X
# 2
# ​
#  =4∣B)⋅P(B)
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# (
# 2
# 6
# ×
# 4
# 9
# ×
# 0.5
# )
# P(B∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4)∝(
# 6
# 2
# ​
#  ×
# 9
# 4
# ​
#  ×0.5)
# Step 4: Compare Probabilities
# Since
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# P(A∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4) is higher than
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# P(B∣X
# 1
# ​
#  =3,X
# 2
# ​
#  =4), Naive Bayes would predict Class A.
